# %% [markdown]
# # Continuous FVM-PINN (Finite Volume Method PINN)
# This notebook runs the exact well-balanced Roe Riemann solver architecture ported from HydroNet.
# It uses a clean `.py` module structure for reproducibility and ease of adding Sediment later.

# %%
# !git clone https://github.com/ATIK2110018/gironde_PINN.git 2>/dev/null || (cd gironde_PINN && git pull origin main)
# !pip install -q torch-geometric netCDF4 xarray matplotlib scipy

# %%
# %cd gironde_PINN/code/fvm_pinn
# !python main.py

# %% [markdown]
# ### View Outputs
# Once training completes, the code automatically generates high-quality visualizations (including GIFs of the wave) in `/kaggle/working/outputs/`.
# You can view them here:

# %%
from IPython.display import Image, display
try:
    display(Image(filename='/kaggle/working/outputs/wave_animation.gif'))
except:
    print("Run the training cell first to generate the animation!")
